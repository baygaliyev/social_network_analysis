# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Anna\\Documents\\UniPi\\II Sem\\Social Network Analysis\\SNA\\data_updated_try_1.csv")
df.head()
# Out:
#    Unnamed: 0 accept_rate display_name  \
# 0           0         100  Jeff Atwood
# 1           1         100  Jeff Atwood
# 2           2         100  Jeff Atwood
# 3           3         100  Jeff Atwood
# 4           4         100  Jeff Atwood
#
#                                             link  \
# 0  https://stackoverflow.com/users/1/jeff-atwood
# 1  https://stackoverflow.com/users/1/jeff-atwood
# 2  https://stackoverflow.com/users/1/jeff-atwood
# 3  https://stackoverflow.com/users/1/jeff-atwood
# 4  https://stackoverflow.com/users/1/jeff-atwood
#
#                                        profile_image  reputation user_id  \
# 0  https://www.gravatar.com/avatar/51d623f33f8b83...     46465.0       1
# 1  https://www.gravatar.com/avatar/51d623f33f8b83...     46465.0       1
# 2  https://www.gravatar.com/avatar/51d623f33f8b83...     46465.0       1
# 3  https://www.gravatar.com/avatar/51d623f33f8b83...     46465.0       1
# 4  https://www.gravatar.com/avatar/51d623f33f8b83...     46465.0       1
#
#     user_type             0     views         0.2     hashtag  \
# 0  registered  1.217514e+09  536898.0  1217547659          c#
# 1  registered  1.217514e+09  313519.0  1228321003         sql
# 2  registered  1.217514e+09  146098.0  1217548537          c#
# 3  registered  1.217514e+09   15793.0  1224837586          c#
# 4  registered  1.217514e+09   27940.0  1219328321  sql-server
#
#                ht1         ht2       ht3                 ht4;
# 0             .net    datetime       NaN                    ;
# 1       sql-server  parameters       NaN                    ;
# 2         datetime        time  datediff  relative-time-span;
# 3             .net   delegates    lambda                    ;
# 4  sql-server-2005    deadlock       NaN                    ;

# %%
df_work=df

# %%
df_work = df_work.drop(["Unnamed: 0", '0', 'display_name',"link", "profile_image", "user_id", "user_type", "0.2"], axis=1)
df_work.head()
# Out:
#   accept_rate  reputation     views     hashtag              ht1         ht2  \
# 0         100     46465.0  536898.0          c#             .net    datetime
# 1         100     46465.0  313519.0         sql       sql-server  parameters
# 2         100     46465.0  146098.0          c#         datetime        time
# 3         100     46465.0   15793.0          c#             .net   delegates
# 4         100     46465.0   27940.0  sql-server  sql-server-2005    deadlock
#
#         ht3                 ht4;
# 0       NaN                    ;
# 1       NaN                    ;
# 2  datediff  relative-time-span;
# 3    lambda                    ;
# 4       NaN                    ;

# %%
# for hashtags only
d = df_work[['hashtag', 'ht1', 'ht2', 'ht3', 'ht4;']]

# %%
df_work['count'] = 0

# %%
count=0
pop=-1
for n in g.nodes():
    if g.degree(n)>400:
        count=count+1
        pop=n
        print(pop, 'degree:', g.degree(pop))
print('count:', count)

# %%
print(df_work.iloc[2847], df_work.iloc[3683], df_work.iloc[3733], df_work.iloc[6102], df_work.iloc[9935])
# Out:
# accept_rate         NaN
# reputation          795
# views             16574
# hashtag              c#
# ht1                .net
# ht2                 wpf
# ht3            winforms
# ht4;                  ;
# count                 4
# ar                  NaN
# Name: 2847, dtype: object accept_rate          92
# reputation         7421
# views               884
# hashtag              c#
# ht1                .net
# ht2             asp.net
# ht3            webforms
# ht4;                  ;
# count                 4
# ar                   92
# Name: 3683, dtype: object accept_rate             50
# reputation          116592
# views                 1315
# hashtag                 c#
# ht1                   .net
# ht2                asp.net
# ht3                   rest
# ht4;           webrequest;
# count                    4
# ar                      50
# Name: 3733, dtype: object accept_rate                   71
# reputation                  1232
# views                        324
# hashtag                       c#
# ht1                         .net
# ht2                      asp.net
# ht3                     webforms
# ht4;           anonymous-access;
# count                          4
# ar                            71
# Name: 6102, dtype: object accept_rate       55.0
# reputation       84338
# views             1060
# hashtag             c#
# ht1               .net
# ht2            asp.net
# ht3             vb.net
# ht4;              clr;
# count                4
# ar                  55
# Name: 9935, dtype: object

# %%
# the most frequent ones
ht_li = ['c#', '.net', 'wpf', 'winforms', 'asp.net', 'webforms', 'rest', 'webrequest', 'anonymous-access', 'vb.net', 'clr']

# %%
def isNaN(num):
    return num != num

# %%
def compare(list1, list2):
    v=0
    for i in list1:
        if i!=';' and isNaN(i)==False:
            if i in list2:
                v+=1
    return v

# %%
for i in range (0, 10001):
    list1=[]
    
    for p in range (0, 4):
        list1.append(d.loc[i][p])
        #print(list1)
    df_work.loc[i, 'count'] = compare(list1, ht_li)

# %%
df_work[413:418]
# Out:
#     accept_rate  reputation         views   hashtag               ht1  \
# 413          74     11387.0  5.040000e+02      .net        namespaces
# 414          -1       455.0  1.535562e+09  circleci        go-modules
# 415          53     11463.0  2.562690e+05      .net  entity-framework
# 416          53     11463.0  7.465600e+04      html               css
# 417          53     11463.0  5.580000e+02      .net      unit-testing
#
#              ht2  ht3 ht4;  count
# 413          NaN  NaN    ;      1
# 414          NaN  NaN    ;      0
# 415  linq-to-sql  NaN    ;      1
# 416          NaN  NaN    ;      0
# 417        nunit  NaN    ;      1

# %%
# bags
for i in range (0,10001):
    if df_work.iloc[i]['accept_rate'] == 'Rob G.' or  df_work.iloc[i]['accept_rate'] == 'Cade' or df_work.iloc[i]['accept_rate'] == 'Joe Mahoney' or df_work.iloc[i]['accept_rate'] == 'Andrea Bertani': 
         df_work.loc[i, 'accept_rate'] = -1

# %%
df_work['ar'] = df_work['accept_rate'].astype(float)

# %%
corr = df_work[['ar', 'reputation', 'views', 'count']].corr()

# %%
df_work.head(20)
# Out:
#    accept_rate  reputation     views        hashtag                ht1  \
# 0          100     46465.0  536898.0             c#               .net
# 1          100     46465.0  313519.0            sql         sql-server
# 2          100     46465.0  146098.0             c#           datetime
# 3          100     46465.0   15793.0             c#               .net
# 4          100     46465.0   27940.0     sql-server    sql-server-2005
# 5          100     46465.0  121204.0     javascript               html
# 6          100     46465.0   10912.0            sql         sql-server
# 7          100     46465.0   14175.0     javascript             jquery
# 8          100     46465.0   59187.0          iis-7              https
# 9          100     46465.0   73915.0       security  language-agnostic
# 10         100     46465.0    6600.0           html  internet-explorer
# 11         100     46465.0    1241.0           .net              regex
# 12         100     46465.0   24643.0           .net           escaping
# 13         100     46465.0    1944.0      algorithm  language-agnostic
# 14         100     46465.0    5707.0     sql-server               tsql
# 15          92      2178.0   22068.0           java            ehcache
# 16          92      2178.0   10613.0           java             tomcat
# 17          92      2178.0  259235.0        windows         batch-file
# 18          92      2178.0    8137.0           ruby             string
# 19          92      2178.0    1526.0  ruby-on-rails               ruby
#
#               ht2                   ht3                 ht4;  count     ar
# 0        datetime                   NaN                    ;      2  100.0
# 1      parameters                   NaN                    ;      0  100.0
# 2            time              datediff  relative-time-span;      1  100.0
# 3       delegates                lambda                    ;      2  100.0
# 4        deadlock                   NaN                    ;      0  100.0
# 5          iframe          framebusting                    ;      0  100.0
# 6            date      gaps-and-islands                    ;      0  100.0
# 7      validation  internationalization                    ;      0  100.0
# 8   url-rewriting    url-rewrite-module                    ;      0  100.0
# 9         captcha                   NaN                    ;      0  100.0
# 10            NaN                   NaN                    ;      0  100.0
# 11           text            formatting                    ;      1  100.0
# 12  string.format                   NaN                    ;      1  100.0
# 13           text                  diff                    ;      0  100.0
# 14            NaN                   NaN                    ;      0  100.0
# 15      multicast                   NaN                    ;      0   92.0
# 16           jdbc                   jmx                    ;      0   92.0
# 17      scripting                   cmd                    ;      0   92.0
# 18           date                 types                    ;      0   92.0
# 19          crash                   NaN                    ;      0   92.0

# %%
corr
# Out:
#                   ar  reputation     views     count
# ar          1.000000   -0.125617 -0.154986 -0.040419
# reputation -0.125617    1.000000 -0.020026  0.103814
# views      -0.154986   -0.020026  1.000000 -0.014001
# count      -0.040419    0.103814 -0.014001  1.000000

# %%
sns.heatmap(corr)
